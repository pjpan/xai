# %%
# !pip install xai
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#     100% |████████████████████████████████| 348kB 4.8MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 14.7MB 1.6MB/s eta 0:00:01   55% |█████████████████▉              | 8.2MB 10.8MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 14.1MB 1.5MB/s ta 0:00:011   42% |█████████████▋                  | 6.0MB 11.1MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 24.5MB 731kB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 7.9MB 2.2MB/s eta 0:00:01
# ...
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/74/68/d87d9b36af36f44254a8d512cbfc48369103a3b9e474be9bdfe536abfc45/python_dateutil-2.7.5-py2.py3-none-any.whl
# ...
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/f8/0e/2365ddc010afb3d79147f1dd544e5ee24bf4ece58ab99b16fbb465ce6dc0/pytz-2018.7-py2.py3-none-any.whl
# ...

# %%
import xai.data

# %%
df = xai.data.load_census()

# %%
df.head(10)
# Out:
#    age          workclass   education  education-num          marital-status  \
# 0   39          State-gov   Bachelors             13           Never-married
# 1   50   Self-emp-not-inc   Bachelors             13      Married-civ-spouse
# 2   38            Private     HS-grad              9                Divorced
# 3   53            Private        11th              7      Married-civ-spouse
# 4   28            Private   Bachelors             13      Married-civ-spouse
# 5   37            Private     Masters             14      Married-civ-spouse
# 6   49            Private         9th              5   Married-spouse-absent
# 7   52   Self-emp-not-inc     HS-grad              9      Married-civ-spouse
# 8   31            Private     Masters             14           Never-married
# 9   42            Private   Bachelors             13      Married-civ-spouse
#
#            occupation    relationship ethnicity   gender  capital-gain  \
# ...

# %%
protected_cols=["age", "gender", "ethnicity"]

# %%
ims=xai.show_imbalance(df, protected_cols)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-5327f52acc39> in <module>()
# ----> 1 ims=xai.show_imbalance(df, protected_cols)
#
# ~/anaconda3/lib/python3.6/site-packages/xai/__init__.py in show_imbalance(df, column_name, cross, categorical_cols, bins, threshold)
#     183             cols,
#     184             bins=bins,
# --> 185             categorical_cols=categorical_cols)
#     186     grouped_col = grouped[column_name]
#     187     count_grp = grouped_col.count()
#
# ~/anaconda3/lib/python3.6/site-packages/xai/__init__.py in group_by_columns(df, columns, bins, categorical_cols)
#     119     for c in columns:
#     120         col = df[c]
# --> 121         if c in categorical_cols or not bins:
#     122             grp = c
#     123         else:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in __contains__(self, key)
# ...
